# %%
# Loading data into Pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('pokemon_data.csv')

# %%
# print first 3 rows
print(df.head(3))
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False

# %%
# print last 3 rows 
print(df.tail(3))
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
# read headers 
print(df.columns)
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
# display a specific column
print(df["Name"])
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
print(df[["Name", "HP"]][0:5])
# Out:
#                     Name  HP
# 0              Bulbasaur  45
# 1                Ivysaur  60
# 2               Venusaur  80
# 3  VenusaurMega Venusaur  80
# 4             Charmander  39

# %%
# read only one row 
print(df.iloc[1])
# Out:
# #                   2
# Name          Ivysaur
# Type 1          Grass
# Type 2         Poison
# HP                 60
# Attack             62
# Defense            63
# Sp. Atk            80
# Sp. Def            80
# Speed              60
# Generation          1
# Legendary       False
# Name: 1, dtype: object

# %%
# read a specific location (Row, Column)
print(df.iloc[1, 1])
# Out:
# Ivysaur

# %%
# iterate over rows
for index, row in df.iterrows():
    print(index, row["Name"])
# Out:
# 0 Bulbasaur
# 1 Ivysaur
# 2 Venusaur
# 3 VenusaurMega Venusaur
# 4 Charmander
# 5 Charmeleon
# 6 Charizard
# 7 CharizardMega Charizard X
# 8 CharizardMega Charizard Y
# 9 Squirtle
# 10 Wartortle
# 11 Blastoise
# 12 BlastoiseMega Blastoise
# 13 Caterpie
# 14 Metapod
# 15 Butterfree
# 16 Weedle
# 17 Kakuna
# 18 Beedrill
# 19 BeedrillMega Beedrill
# 20 Pidgey
# 21 Pidgeotto
# 22 Pidgeot
# 23 PidgeotMega Pidgeot
# 24 Rattata
# 25 Raticate
# 26 Spearow
# 27 Fearow
# 28 Ekans
# 29 Arbok
# 30 Pikachu
# 31 Raichu
# 32 Sandshrew
# 33 Sandslash
# 34 Nidoran (Female)
# 35 Nidorina
# 36 Nidoqueen
# 37 Nidoran (Male)
# 38 Nidorino
# 39 Nidoking
# 40 Clefairy
# 41 Clefable
# 42 Vulpix
# 43 Ninetales
# 44 Jigglypuff
# 45 Wigglytuff
# 46 Zubat
# 47 Golbat
# 48 Oddish
# 49 Gloom
# 50 Vileplume
# 51 Paras
# 52 Parasect
# 53 Venonat
# 54 Venomoth
# 55 Diglett
# 56 Dugtrio
# 57 Meowth
# 58 Persian
# 59 Psyduck
# 60 Golduck
# 61 Mankey
# 62 Primeape
# 63 Growlithe
# 64 Arcanine
# 65 Poliwag
# ...

# %%
# get rows which satisfy some condition
df.loc[df["Type 1"] == "Fire"]
# Out:
#        #                       Name Type 1    Type 2   HP  Attack  Defense  \
# 4      4                 Charmander   Fire       NaN   39      52       43
# 5      5                 Charmeleon   Fire       NaN   58      64       58
# 6      6                  Charizard   Fire    Flying   78      84       78
# 7      6  CharizardMega Charizard X   Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y   Fire    Flying   78     104       78
# 42    37                     Vulpix   Fire       NaN   38      41       40
# 43    38                  Ninetales   Fire       NaN   73      76       75
# 63    58                  Growlithe   Fire       NaN   55      70       45
# 64    59                   Arcanine   Fire       NaN   90     110       80
# 83    77                     Ponyta   Fire       NaN   50      85       55
# 84    78                   Rapidash   Fire       NaN   65     100       70
# ...

# %%
# get info about the data
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
df.sort_values("Name", ascending=False)
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 46    41                    Zubat   Poison  Flying   40      45       35
# 631  570                    Zorua     Dark     NaN   40      65       40
# 632  571                  Zoroark     Dark     NaN   60     105       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# 392  359                    Absol     Dark     NaN   65     130       60
# 68    63                     Abra  Psychic     NaN   25      20       15
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 510  460                Abomasnow    Grass     Ice   90      92       75
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
# making changes to data

# %%
df["Total"] = df["HP"] + df["Attack"]
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False     94
# 1       80     60           1      False    122
# 2      100     80           1      False    162
# 3      120     80           1      False    180
# 4       50     65           1      False     91

# %%
# drop column
df = df.drop(columns=["Total"])
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
# saving
df.to_csv("pokemon_modified.csv", index=False)

# %%
# filtering data
new_df = df.loc[(df["Type 1"] == "Grass") & (df["Type 2"] == "Poison")]

# %%
new_df
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 48    43                 Oddish  Grass  Poison   45      50       55       75
# 49    44                  Gloom  Grass  Poison   60      65       70       85
# 50    45              Vileplume  Grass  Poison   75      80       85      110
# 75    69             Bellsprout  Grass  Poison   50      75       35       70
# 76    70             Weepinbell  Grass  Poison   65      90       50       85
# 77    71             Victreebel  Grass  Poison   80     105       65      100
# 344  315                Roselia  Grass  Poison   50      60       45      100
# ...

# %%
new_df = new_df.reset_index()
# Out:
#     index    #                   Name Type 1  Type 2   HP  Attack  Defense  \
# 0       0    1              Bulbasaur  Grass  Poison   45      49       49
# 1       1    2                Ivysaur  Grass  Poison   60      62       63
# 2       2    3               Venusaur  Grass  Poison   80      82       83
# 3       3    3  VenusaurMega Venusaur  Grass  Poison   80     100      123
# 4      48   43                 Oddish  Grass  Poison   45      50       55
# 5      49   44                  Gloom  Grass  Poison   60      65       70
# 6      50   45              Vileplume  Grass  Poison   75      80       85
# 7      75   69             Bellsprout  Grass  Poison   50      75       35
# 8      76   70             Weepinbell  Grass  Poison   65      90       50
# 9      77   71             Victreebel  Grass  Poison   80     105       65
# 10    344  315                Roselia  Grass  Poison   50      60       45
# ...

# %%
# conditional changes 
df.loc[df["Type 1"] == "Fire", "Type 1"] = "Flame!!!"

# %%
print(df)
# Out:
#        #                   Name    Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur     Grass  Poison  45      49       49
# 1      2                Ivysaur     Grass  Poison  60      62       63
# 2      3               Venusaur     Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur     Grass  Poison  80     100      123
# 4      4             Charmander  Flame!!!     NaN  39      52       43
# ..   ...                    ...       ...     ...  ..     ...      ...
# 795  719                Diancie      Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie      Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined   Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound   Psychic    Dark  80     160       60
# 799  721              Volcanion  Flame!!!   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.loc[df["HP"] > 30, ["Attack", "Defense"]] = [10, 20]

# %%
print(df)
# Out:
#        #                   Name    Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur     Grass  Poison  45      10       20
# 1      2                Ivysaur     Grass  Poison  60      10       20
# 2      3               Venusaur     Grass  Poison  80      10       20
# 3      3  VenusaurMega Venusaur     Grass  Poison  80      10       20
# 4      4             Charmander  Flame!!!     NaN  39      10       20
# ..   ...                    ...       ...     ...  ..     ...      ...
# 795  719                Diancie      Rock   Fairy  50      10       20
# 796  719    DiancieMega Diancie      Rock   Fairy  50      10       20
# 797  720    HoopaHoopa Confined   Psychic   Ghost  80      10       20
# 798  720     HoopaHoopa Unbound   Psychic    Dark  80      10       20
# 799  721              Volcanion  Flame!!!   Water  80      10       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
# agregate statistics

# %%
df.groupby(["Type 1"]).mean()
# Out:
# C:\Users\oskar\AppData\Local\Temp\ipykernel_14088\4224353277.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(["Type 1"]).mean()
#                    #         HP     Attack    Defense    Sp. Atk    Sp. Def  \
# Type 1
# Bug       334.492754  56.884058  11.956522  24.289855  53.869565  64.797101
# Dark      461.354839  66.806452  10.000000  20.000000  74.645161  69.516129
# Dragon    474.375000  83.312500  10.000000  20.000000  96.843750  88.843750
# Electric  363.500000  59.795455  11.250000  21.022727  90.022727  73.704545
# Fairy     449.529412  74.117647  10.000000  20.000000  78.529412  84.705882
# Fighting  363.851852  69.851852  11.111111  21.296296  53.111111  64.703704
# Flame!!!  327.403846  69.903846  10.000000  20.000000  88.980769  72.211538
# ...
